# %% [markdown]
# # Week 5 Assignment — Statistical Analysis Project
#
# **Course:** Introduction to Data Science
# **Assignment Goal:** Write a short statistical report.
#
# ## Instructions
#
# Use the cleaned employee dataset from previous weeks, or another simple
# dataset approved by the instructor.

# %% [markdown]
# ## Tasks
#
# - Load and inspect the dataset.
# - Choose two numeric columns for analysis.
# - For each numeric column, calculate mean, median, minimum, maximum, range, and standard deviation.
# - Create one histogram for each numeric column.
# - Choose one categorical column and compare the average of one numeric column across its groups.
# - Calculate and interpret the correlation between two numeric columns.
# - Write a short report with 5-7 findings.
#
# ## Submission
#
# - Submit one notebook or script.
# - Submit a short written findings section inside the notebook.
# - Include at least two charts.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("data/employee_data_cleaned.csv")

# %%
# Descriptive statistics for two numeric columns
numeric_columns = ["score", "attendance"]

for col in numeric_columns:
    # Your code here: mean, median, min, max, range, std
    pass

# %%
# One histogram per numeric column

# %%
# Compare a numeric column's average across a categorical column's groups

# %%
# Correlation between two numeric columns

# %% [markdown]
# ## Findings
#
# *Write 5-7 findings here.*
#
# ---
# See [assignment-solution.ipynb](assignment-solution.ipynb) for a reference solution.
