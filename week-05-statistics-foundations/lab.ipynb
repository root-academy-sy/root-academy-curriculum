# %% [markdown]
# # Week 5 Lab — Statistics Foundations
#
# **Course:** Introduction to Data Science
# **Lab Goal:** Perform a short statistical analysis.
#
# ## Dataset
#
# Use the cleaned dataset from Week 3: [`data/employee_data_cleaned.csv`](data/employee_data_cleaned.csv).

# %% [markdown]
# ## Tasks
#
# - Load the dataset using Pandas.
# - Print summary statistics using `describe()`.
# - Calculate mean, median, minimum, maximum, range, and standard deviation for `score`.
# - Calculate the average score by department.
# - Find the department with the highest average score.
# - Calculate the correlation between attendance and score.
# - Create one histogram for score.
# - Write three short findings from your analysis.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("data/employee_data_cleaned.csv")

print(df.describe())

# %%
# Mean, median, minimum, maximum, range, and standard deviation for score

# %%
# Average score by department, and the highest-scoring department

# %%
# Correlation between attendance and score

# %%
# Histogram of score

# %% [markdown]
# ## Findings
#
# *Write three short findings here.*
#
# ---
# See [lab-solution.ipynb](lab-solution.ipynb) for a reference solution.
