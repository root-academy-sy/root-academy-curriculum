# %% [markdown]
# # Week 8 Assignment — Final Capstone Submission
#
# **Course:** Introduction to Data Science
# **Assignment Goal:** Submit and present your final project.
#
# This brings together everything from Weeks 3-7: cleaning, EDA, visualization,
# statistics, and (optionally) a simple ML model — applied end-to-end to one
# dataset of your choice.

# %% [markdown]
# ## Required Sections
#
# - Project title and problem statement.
# - Dataset description.
# - Cleaning steps.
# - At least three EDA questions, answered.
# - At least three charts.
# - Basic statistics (mean, correlation, or group comparison).
# - Optional: a simple ML model (regression or classification).
# - Findings (at least four).
# - Conclusion and next steps.
#
# ## Submit
#
# - Final notebook.
# - Cleaned dataset (CSV).
# - A short presentation (slides or a written summary) — 5-7 slides/sections.
#
# ## Grading Criteria
#
# | Criteria | Weight |
# |---|---|
# | Data cleaning | 20% |
# | EDA and statistics | 25% |
# | Visualizations | 25% |
# | Conclusion | 15% |
# | Presentation clarity | 15% |

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your dataset (your own, or the course's employee dataset)

# %% [markdown]
# **Problem statement:** *Write it here.*

# %%
# Cleaning steps

# %%
# EDA questions, answered (at least three)

# %%
# Charts (at least three)

# %%
# Basic statistics

# %%
# Optional: a simple ML model

# %% [markdown]
# ## Findings
#
# *Write at least four findings here.*
#
# ## Conclusion and next steps
#
# *Write your conclusion here.*
#
# ---
# See [assignment-solution.ipynb](assignment-solution.ipynb) for the instructor rubric.
