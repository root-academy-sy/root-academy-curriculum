# %% [markdown]
# # Week 8 Lab — Capstone Planning & Presentation Practice
#
# **Course:** Introduction to Data Science
# **Lab Goal:** Finalize your capstone plan and prepare your presentation.
#
# You can use your own dataset, or continue with the employee dataset from
# Weeks 3-7: [`data/employee_data_cleaned.csv`](data/employee_data_cleaned.csv).

# %% [markdown]
# ## Part 1: Capstone Planning
#
# - Choose a dataset (your own, or the course's employee dataset).
# - Write a problem statement.
# - List 5 questions you want to answer.
# - Confirm your dataset is cleaned (reuse your Week 3 cleaning steps if using
#   the employee dataset).
# - Create at least two charts.
# - Write a draft conclusion.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("data/employee_data_cleaned.csv")

# %% [markdown]
# **Problem statement:** *Write it here.*
#
# **Five questions:**
# 1.
# 2.
# 3.
# 4.
# 5.

# %%
# At least two charts

# %% [markdown]
# **Draft conclusion:** *Write it here.*
#
# ## Part 2: Presentation Practice
#
# - Create 5-7 presentation slides (a slide deck tool of your choice, or
#   markdown cells here as a lightweight version).
# - Include the problem, dataset, cleaning, findings, and conclusion.
# - Use at least three charts.
# - Practice a 5-minute presentation.
# - Prepare one answer to: *What would you improve next?*

# %% [markdown]
# ### Slide outline
#
# 1. Title and your name
# 2. Problem statement
# 3. Dataset overview
# 4. Cleaning summary
# 5-6. Main findings (with charts)
# 7. Conclusion and next steps
#
# *Fill in your actual slide content here, or link to your slides.*
#
# ---
# See [lab-solution.ipynb](lab-solution.ipynb) for a worked example.
