# %% [markdown]
# # Week 2 Lab — NumPy and Pandas
#
# **Course:** Introduction to Data Science
# **Lab Goal:** Load, inspect, and clean a small dataset.
#
# ## Dataset
#
# The dataset for this lab is provided at [`data/employee_scores.csv`](data/employee_scores.csv):
#
# ```
# name,department,score,attendance
# Ali,IT,88,92
# Maya,HR,74,85
# Omar,Finance,91,90
# Lina,IT,,78
# Sara,HR,95,
# Ali,IT,88,92
# ```
#
# If you're running this notebook somewhere other than the repo (e.g. Colab
# without the repo mounted), create this CSV yourself with the same content.

# %% [markdown]
# ## Tasks
#
# - Import NumPy and Pandas.
# - Load the CSV file into a DataFrame.
# - Print `head()`, `shape`, `info()`, and `describe()`.
# - Count missing values and duplicates.
# - Remove duplicates.
# - Fill missing `score` and `attendance` values with the column mean.
# - Create a `category` column from `score`.
# - Save `employee_scores_cleaned.csv`.

# %%
# Import NumPy and Pandas

# %%
# Load the CSV file into a DataFrame

# %%
# Print head(), shape, info(), and describe()

# %%
# Count missing values and duplicates

# %%
# Remove duplicates

# %%
# Fill missing score and attendance values with the column mean

# %%
# Create a category column from score
def classify(score):
    # Your code here
    pass

# %%
# Save employee_scores_cleaned.csv

# %% [markdown]
# ---
# See [lab-solution.ipynb](lab-solution.ipynb) for a reference solution.
