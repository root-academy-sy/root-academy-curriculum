# %% [markdown]
# # Week 2 Assignment — Clean a Dataset
#
# **Course:** Introduction to Data Science
# **Assignment Goal:** Practice basic Pandas cleaning.
#
# ## Dataset
#
# Use the provided [`data/employee_scores.csv`](data/employee_scores.csv) file
# from the lab, or create your own similar file with at least 8 rows.

# %% [markdown]
# ## Tasks
#
# - Load the dataset using Pandas.
# - Rename columns using lowercase names with underscores.
# - Check missing values and duplicates.
# - Handle missing numeric values using mean or median.
# - Create a `final_score` column: `score * 0.7 + attendance * 0.3`.
# - Group by department and calculate count and average `final_score`.
# - Save the cleaned file as `assignment_week2_cleaned.csv`.
#
# ## Submission
#
# Submit the notebook and the cleaned CSV file.

# %%
# Load the dataset using Pandas

# %%
# Rename columns using lowercase names with underscores

# %%
# Check missing values and duplicates

# %%
# Handle missing numeric values using mean or median

# %%
# Create a final_score column: score * 0.7 + attendance * 0.3

# %%
# Group by department: count and average final_score

# %%
# Save the cleaned file as assignment_week2_cleaned.csv

# %% [markdown]
# ---
# See [assignment-solution.ipynb](assignment-solution.ipynb) for a reference solution.
