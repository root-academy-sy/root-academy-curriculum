# %% [markdown]
# # Week 1 Lab — Python Foundations
#
# **Course:** Introduction to Data Science
# **Lab Goal:** Build a small grade analyzer.
#
# ## Instructions
#
# Complete the exercises below. Run each cell, and make sure your outputs are
# visible before submitting. Save your work as this notebook (`.ipynb`).

# %% [markdown]
# ## Part 1: Warm-up
#
# - Create variables for a student name, grade, and department.
# - Print a sentence using an f-string.

# %%
# Your code here
student_name = ...
grade = ...
department = ...

# Print a sentence using an f-string

# %% [markdown]
# ## Part 2: Lists
#
# Use this list:
#
# ```python
# grades = [85, 92, 78, 55, 67]
# ```
#
# - Print the number of grades.
# - Calculate the average.
# - Print the highest and lowest grade.
# - Count how many grades are 60 or above.

# %%
grades = [85, 92, 78, 55, 67]

# Number of grades


# Average


# Highest and lowest grade


# Count grades >= 60

# %% [markdown]
# ## Part 3: Dictionaries
#
# Use this data:
#
# ```python
# students = [
#     {"name": "Ali", "grade": 85},
#     {"name": "Maya", "grade": 92},
#     {"name": "Omar", "grade": 55}
# ]
# ```
#
# - Print each student name and grade.
# - Add a category: Excellent, Good, Pass, or Fail.
# - Write a function called `classify_grade(grade)`.

# %%
students = [
    {"name": "Ali", "grade": 85},
    {"name": "Maya", "grade": 92},
    {"name": "Omar", "grade": 55}
]

def classify_grade(grade):
    # Your code here
    pass

# Print each student name, grade, and category

# %% [markdown]
# ## Part 4: File Input / Output
#
# - Write the `students` list from Part 3 to a file called `students.txt`, one line per student in the format `name,grade`.
# - Read `students.txt` back in, parse each line, and rebuild a list of dictionaries `{"name": ..., "grade": ...}`.
# - Print the reloaded list to confirm it matches the original data.
#
# Tips: use `with open(...) as f:` for both writing and reading, and `.strip().split(",")` to parse each line.

# %%
# Write students to students.txt


# Read students.txt back in and rebuild the list of dicts


# Print the reloaded list

# %% [markdown]
# ## Part 5: Challenge — Class Report Card
#
# Use this data:
#
# ```python
# class_data = {
#     "Math":    [85, 92, 78, 55, 67],
#     "Science": [70, 88, 91, 60, 45],
#     "History": [95, 60, 73, 82, 58]
# }
# ```
#
# Write a function `report_card(class_data)` that returns a dictionary where each
# subject maps to a summary dictionary with:
# - `"average"`: the average grade for that subject (rounded to 1 decimal)
# - `"top_score"`: the highest grade
# - `"pass_rate"`: percentage of grades >= 60 (rounded to 1 decimal)
#
# Then:
# - Find and print which subject has the highest class average.
# - Find and print which subject has the lowest pass rate.
# - Print the full report in a readable format (one line per subject).
#
# No `pandas` or `numpy` — plain Python only (loops, `sum()`, `max()`, etc.).

# %%
class_data = {
    "Math":    [85, 92, 78, 55, 67],
    "Science": [70, 88, 91, 60, 45],
    "History": [95, 60, 73, 82, 58]
}

def report_card(class_data):
    # Your code here
    pass

# Build the report


# Subject with highest average


# Subject with lowest pass rate


# Print the full report
