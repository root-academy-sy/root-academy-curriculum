# %% [markdown]
# # Week 1 Assignment — Employee Performance Analyzer
#
# **Course:** Introduction to Data Science
# **Assignment Goal:** Analyze employee scores using basic Python.

# %% [markdown]
# ## Dataset

# %%
employees = [
    {"name": "Ali", "department": "IT", "score": 88},
    {"name": "Maya", "department": "HR", "score": 74},
    {"name": "Omar", "department": "Finance", "score": 91},
    {"name": "Lina", "department": "IT", "score": 67},
    {"name": "Sara", "department": "HR", "score": 95}
]

# %% [markdown]
# ## Tasks
#
# 1. Print all employee names and scores.
# 2. Calculate the average score.
# 3. Find the highest and lowest score.
# 4. Count employees with score 80 or above.
# 5. Classify each employee as **Excellent**, **Good**, **Satisfactory**, or **Needs Improvement**.
# 6. Write a short summary to `performance_summary.txt`.

# %%
# 1. Print all employee names and scores

# %%
# 2. Calculate the average score

# %%
# 3. Find the highest and lowest score

# %%
# 4. Count employees with score 80 or above

# %%
# 5. Classify each employee
def classify(score):
    # Your code here
    pass

# %%
# 6. Write a short summary to performance_summary.txt

# %% [markdown]
# ## Optional Challenge
#
# - Calculate the average score by department.

# %%
# Optional challenge: average score by department
