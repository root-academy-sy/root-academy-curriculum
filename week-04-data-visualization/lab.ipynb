# %% [markdown]
# # Week 4 Lab — Data Visualization
#
# **Course:** Introduction to Data Science
# **Lab Goal:** Create a short visual report.
#
# ## Dataset
#
# Use the cleaned dataset from Week 3: [`data/employee_data_cleaned.csv`](data/employee_data_cleaned.csv).

# %% [markdown]
# ## Tasks
#
# - Import Pandas, Matplotlib, and Seaborn.
# - Create a bar chart of average score by department.
# - Create a histogram of scores.
# - Create a box plot of score by department.
# - Create a scatter plot of attendance vs score.
# - Add titles and axis labels to every chart.
# - Write one sentence interpreting each chart.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("data/employee_data_cleaned.csv")

# %%
# Bar chart: average score by department

# %%
# Histogram of scores

# %%
# Box plot of score by department

# %%
# Scatter plot of attendance vs score

# %% [markdown]
# ## Interpretations
#
# *Write one sentence per chart here.*
#
# ---
# See [lab-solution.ipynb](lab-solution.ipynb) for a reference solution.
