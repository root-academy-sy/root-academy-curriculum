# %% [markdown]
# # Week 4 Assignment — Visual Report
#
# **Course:** Introduction to Data Science
# **Assignment Goal:** Communicate findings using charts.
#
# ## Dataset
#
# Use the cleaned dataset from Week 3: [`data/employee_data_cleaned.csv`](data/employee_data_cleaned.csv).

# %% [markdown]
# ## Tasks
#
# - Use a cleaned dataset.
# - Create at least four different charts.
# - Each chart must have a title, x-axis label, and y-axis label.
# - Write 2-3 sentences below each chart explaining what it shows.
# - Save at least two charts as PNG files.
# - End with a short conclusion of 4-5 bullet points.
#
# ## Required Charts
#
# - One bar chart.
# - One histogram.
# - One box plot or scatter plot.
# - One chart of your choice.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("data/employee_data_cleaned.csv")

# %%
# Bar chart (save as PNG)

# %%
# Histogram (save as PNG)

# %%
# Box plot or scatter plot

# %%
# Chart of your choice

# %% [markdown]
# ## Conclusion
#
# *Write 4-5 bullet points here.*
#
# ---
# See [assignment-solution.ipynb](assignment-solution.ipynb) for a reference solution.
