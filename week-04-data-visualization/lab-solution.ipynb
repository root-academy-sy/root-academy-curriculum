# %% [markdown]
# # Week 4 Lab Solution — Data Visualization
#
# **Course:** Introduction to Data Science
#
# > ⚠️ Reference solution for instructor/student release.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("data/employee_data_cleaned.csv")

plt.figure(figsize=(8, 5))
sns.barplot(data=df, x="department", y="score")
plt.title("Average Score by Department")
plt.xlabel("Department")
plt.ylabel("Average Score")
plt.tight_layout()
plt.show()

plt.figure(figsize=(8, 5))
sns.histplot(data=df, x="score", bins=10)
plt.title("Distribution of Scores")
plt.xlabel("Score")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x="department", y="score")
plt.title("Score Distribution by Department")
plt.xlabel("Department")
plt.ylabel("Score")
plt.tight_layout()
plt.show()

plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x="attendance", y="score", hue="department")
plt.title("Attendance vs Score")
plt.xlabel("Attendance")
plt.ylabel("Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Interpretations
#
# - HR has the highest average score of the three departments, though the gap
#   to IT is modest.
# - Most scores cluster between 70 and 90, with a small number above 90.
# - Finance shows the widest spread of scores, from the lowest to a strong
#   performer.
# - Attendance and score trend together — employees with higher attendance
#   tend to score higher.
