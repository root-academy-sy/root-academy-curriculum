# %% [markdown]
# # Week 3 Lab — Data Cleaning and EDA
#
# **Course:** Introduction to Data Science
# **Lab Goal:** Build a short EDA notebook.
#
# ## Dataset
#
# Use [`data/employee_data.csv`](data/employee_data.csv), with columns:
# `employee_id, name, department, score, attendance, salary`.

# %% [markdown]
# ## Tasks
#
# - Load the dataset and inspect the first rows.
# - Clean column names.
# - Check missing values and duplicates.
# - Standardize department names such as IT, I.T., and Information Technology.
# - Convert score, attendance, and salary to numeric.
# - Create a `performance_category` column.
# - Answer three EDA questions using `groupby` or `value_counts`.
# - Write three short findings in markdown or comments.
#
# ## Example Questions
#
# - Which department has the highest average score?
# - How many employees are in each performance category?
# - What is the average salary by department?

# %%
# Load the dataset and inspect the first rows
import pandas as pd

# %%
# Clean column names

# %%
# Check missing values and duplicates

# %%
# Standardize department names

# %%
# Convert score, attendance, and salary to numeric; handle missing values

# %%
# Create a performance_category column
def performance_category(score):
    # Your code here
    pass

# %%
# Answer three EDA questions using groupby or value_counts

# %% [markdown]
# ## Findings
#
# *Write three short findings here.*
#
# ---
# See [lab-solution.ipynb](lab-solution.ipynb) for a reference solution.
