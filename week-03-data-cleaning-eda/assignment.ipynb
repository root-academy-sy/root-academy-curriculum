# %% [markdown]
# # Week 3 Assignment — EDA Notebook
#
# **Course:** Introduction to Data Science
# **Assignment Goal:** Submit a short exploratory analysis.
#
# ## Dataset
#
# Choose or use the provided [`data/employee_data.csv`](data/employee_data.csv).

# %% [markdown]
# ## Tasks
#
# - Clean column names and text categories.
# - Handle missing values and duplicates.
# - Create at least one new useful column.
# - Answer five EDA questions using Pandas.
# - Write a short conclusion with 4-6 findings.
#
# ## Required Output
#
# - One notebook or script.
# - One cleaned CSV file.
# - A short findings section.

# %%
import pandas as pd

df = pd.read_csv("data/employee_data.csv")

# %%
# Clean column names and text categories

# %%
# Handle missing values and duplicates

# %%
# Create at least one new useful column

# %%
# Answer five EDA questions using Pandas
# 1.
# 2.
# 3.
# 4.
# 5.

# %%
# Save the cleaned CSV file

# %% [markdown]
# ## Findings
#
# *Write 4-6 findings here.*
#
# ---
# See [assignment-solution.ipynb](assignment-solution.ipynb) for a reference solution.
