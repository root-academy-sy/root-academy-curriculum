# %% [markdown]
# # Week 6 Assignment — Regression Project
#
# **Course:** Introduction to Data Science
# **Assignment Goal:** Predict a continuous value.
#
# ## Dataset
#
# Use the cleaned dataset from Week 3: [`data/employee_data_cleaned.csv`](data/employee_data_cleaned.csv).

# %% [markdown]
# ## Tasks
#
# - Use a dataset with at least two numeric columns.
# - Choose one numeric target to predict.
# - Use one or more numeric features.
# - Train a `LinearRegression` model.
# - Evaluate using MAE and R2.
# - Write 4-5 sentences explaining whether the model is useful.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score

df = pd.read_csv("data/employee_data_cleaned.csv")

# %%
# Choose target and feature(s)

# %%
# Split into training and testing sets

# %%
# Train the model and evaluate with MAE and R2

# %% [markdown]
# ## Discussion
#
# *Write 4-5 sentences here.*
#
# ---
# See [assignment-solution.ipynb](assignment-solution.ipynb) for a reference solution.
