# %% [markdown]
# # Week 6 Lab — Regression
#
# **Course:** Introduction to Data Science
# **Lab Goal:** Train a simple regression model.
#
# ## Dataset
#
# Use the cleaned dataset from Week 3: [`data/employee_data_cleaned.csv`](data/employee_data_cleaned.csv).

# %% [markdown]
# ## Tasks
#
# - Load a cleaned dataset.
# - Select one numeric feature such as `attendance`.
# - Select one numeric target such as `score`.
# - Split the data into training and testing sets.
# - Train a `LinearRegression` model.
# - Print MAE, MSE, and R2.
# - Write two sentences explaining the model result.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

df = pd.read_csv("data/employee_data_cleaned.csv")

# %%
# Select feature(s) and target

# %%
# Split into training and testing sets

# %%
# Train a LinearRegression model

# %%
# Predict and print MAE, MSE, and R2

# %% [markdown]
# ## Result
#
# *Write two sentences explaining the model result here.*
#
# ---
# See [lab-solution.ipynb](lab-solution.ipynb) for a reference solution.
