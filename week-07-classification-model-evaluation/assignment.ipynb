# %% [markdown]
# # Week 7 Assignment — Classification & Model Comparison Project
#
# **Course:** Introduction to Data Science
# **Assignment Goal:** Predict a category, then evaluate and compare models.
#
# ## Dataset
#
# Use the cleaned dataset from Week 3: [`data/employee_data_cleaned.csv`](data/employee_data_cleaned.csv).

# %% [markdown]
# ## Part 1: Classification
#
# - Create a category target from a numeric column.
# - Choose one or more features.
# - Train a classification model.
# - Evaluate with accuracy and confusion matrix.
# - Write a short explanation of correct and incorrect predictions.
#
# ## Part 2: Model Comparison
#
# - Train a second, different model on the same data.
# - Evaluate both models using appropriate metrics.
# - Create a small comparison table.
# - Write a recommendation: which model would you choose and why?

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

df = pd.read_csv("data/employee_data_cleaned.csv")

# %%
# Create a category target and choose feature(s)

# %%
# Split into training and testing sets

# %%
# Train the first classification model and evaluate it

# %%
# Train a second model and compare accuracy

# %% [markdown]
# ## Comparison Table
#
# | Model | Metric | Result |
# |---|---|---|
# | *Model 1* | Accuracy | *...* |
# | *Model 2* | Accuracy | *...* |
#
# ## Recommendation
#
# *Write your recommendation here.*
#
# ---
# See [assignment-solution.ipynb](assignment-solution.ipynb) for a reference solution.
