# %% [markdown]
# # Week 7 Lab — Classification & Model Evaluation
#
# **Course:** Introduction to Data Science
# **Lab Goal:** Train a classification model, then compare it against a
# second model.
#
# ## Dataset
#
# Use the cleaned dataset from Week 3: [`data/employee_data_cleaned.csv`](data/employee_data_cleaned.csv).

# %% [markdown]
# ## Part 1: Classification
#
# - Load the cleaned dataset.
# - Create a target column called `high_performer` where score is 80 or above.
# - Use `attendance` as a feature.
# - Train a `DecisionTreeClassifier`.
# - Print accuracy, confusion matrix, and classification report.
# - Write two findings.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

df = pd.read_csv("data/employee_data_cleaned.csv")

# %%
# Create the high_performer target column

# %%
# Split into training and testing sets

# %%
# Train a DecisionTreeClassifier and print accuracy, confusion matrix, classification report

# %% [markdown]
# ## Part 2: Model Evaluation
#
# - Train a `LogisticRegression` model on the same train/test split.
# - Compare its accuracy against the Decision Tree.
# - Print the confusion matrix for the better-performing model.
# - Write which model performed better and why you think that might be.

# %%
# Train LogisticRegression and compare accuracy against the Decision Tree

# %%
# Confusion matrix for the better-performing model

# %% [markdown]
# ## Findings
#
# *Write your findings from both parts here.*
#
# ---
# See [lab-solution.ipynb](lab-solution.ipynb) for a reference solution.
